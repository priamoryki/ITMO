# %% [markdown]
# ### Читаем данные

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_absolute_percentage_error

data = pd.read_csv("data/train.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206474 entries, 0 to 206473
# Data columns (total 76 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   city                                 206474 non-null  object
#  1   floor                                76209 non-null   float64
#  2   id                                   206474 non-null  object
#  3   lat                                  206474 non-null  float64
#  4   lng                                  206474 non-null  float64
#  5   osm_amenity_points_in_0.001          206474 non-null  int64
#  6   osm_amenity_points_in_0.005          206474 non-null  int64
#  7   osm_amenity_points_in_0.0075         206474 non-null  int64
#  8   osm_amenity_points_in_0.01           206474 non-null  int64
#  9   osm_building_points_in_0.001         206474 non-null  int64
#  10  osm_building_points_in_0.005         206474 non-null  int64
#  11  osm_building_points_in_0.0075        206474 non-null  int64
#  12  osm_building_points_in_0.01          206474 non-null  int64
#  13  osm_catering_points_in_0.001         206474 non-null  int64
#  14  osm_catering_points_in_0.005         206474 non-null  int64
#  15  osm_catering_points_in_0.0075        206474 non-null  int64
#  16  osm_catering_points_in_0.01          206474 non-null  int64
#  17  osm_city_closest_dist                206474 non-null  float64
#  18  osm_city_nearest_name                206474 non-null  object
#  19  osm_city_nearest_population          206439 non-null  float64
#  20  osm_crossing_closest_dist            206474 non-null  float64
#  21  osm_crossing_points_in_0.001         206474 non-null  int64
#  22  osm_crossing_points_in_0.005         206474 non-null  int64
#  23  osm_crossing_points_in_0.0075        206474 non-null  int64
#  24  osm_crossing_points_in_0.01          206474 non-null  int64
#  25  osm_culture_points_in_0.001          206474 non-null  int64
#  26  osm_culture_points_in_0.005          206474 non-null  int64
#  27  osm_culture_points_in_0.0075         206474 non-null  int64
#  28  osm_culture_points_in_0.01           206474 non-null  int64
#  29  osm_finance_points_in_0.001          206474 non-null  int64
#  30  osm_finance_points_in_0.005          206474 non-null  int64
#  31  osm_finance_points_in_0.0075         206474 non-null  int64
#  32  osm_finance_points_in_0.01           206474 non-null  int64
#  33  osm_healthcare_points_in_0.005       206474 non-null  int64
#  34  osm_healthcare_points_in_0.0075      206474 non-null  int64
#  35  osm_healthcare_points_in_0.01        206474 non-null  int64
#  36  osm_historic_points_in_0.005         206474 non-null  int64
#  37  osm_historic_points_in_0.0075        206474 non-null  int64
#  38  osm_historic_points_in_0.01          206474 non-null  int64
#  39  osm_hotels_points_in_0.005           206474 non-null  int64
#  40  osm_hotels_points_in_0.0075          206474 non-null  int64
#  41  osm_hotels_points_in_0.01            206474 non-null  int64
#  42  osm_leisure_points_in_0.005          206474 non-null  int64
#  43  osm_leisure_points_in_0.0075         206474 non-null  int64
#  44  osm_leisure_points_in_0.01           206474 non-null  int64
#  45  osm_offices_points_in_0.001          206474 non-null  int64
#  46  osm_offices_points_in_0.005          206474 non-null  int64
#  47  osm_offices_points_in_0.0075         206474 non-null  int64
#  48  osm_offices_points_in_0.01           206474 non-null  int64
#  49  osm_shops_points_in_0.001            206474 non-null  int64
#  50  osm_shops_points_in_0.005            206474 non-null  int64
#  51  osm_shops_points_in_0.0075           206474 non-null  int64
#  52  osm_shops_points_in_0.01             206474 non-null  int64
#  53  osm_subway_closest_dist              206474 non-null  float64
#  54  osm_train_stop_closest_dist          206474 non-null  float64
#  55  osm_train_stop_points_in_0.005       206474 non-null  int64
#  56  osm_train_stop_points_in_0.0075      206474 non-null  int64
#  57  osm_train_stop_points_in_0.01        206474 non-null  int64
#  58  osm_transport_stop_closest_dist      206474 non-null  float64
#  59  osm_transport_stop_points_in_0.005   206474 non-null  int64
#  60  osm_transport_stop_points_in_0.0075  206474 non-null  int64
#  61  osm_transport_stop_points_in_0.01    206474 non-null  int64
#  62  per_square_meter_price               206474 non-null  float64
#  63  reform_count_of_houses_1000          206474 non-null  int64
#  64  reform_count_of_houses_500           206474 non-null  int64
#  65  reform_house_population_1000         195541 non-null  float64
#  66  reform_house_population_500          186141 non-null  float64
#  67  reform_mean_floor_count_1000         193961 non-null  float64
#  68  reform_mean_floor_count_500          183936 non-null  float64
#  69  reform_mean_year_building_1000       194311 non-null  float64
#  70  reform_mean_year_building_500        184340 non-null  float64
#  71  region                               206474 non-null  object
#  72  total_square                         206474 non-null  float64
#  73  street                               205271 non-null  object
#  74  date                                 206474 non-null  object
#  75  realty_type                          206474 non-null  int64
# dtypes: float64(17), int64(53), object(6)
# memory usage: 119.7+ MB

# %%
data.corrwith(data.per_square_meter_price)
# Out:
# C:\Users\Xiaomi\AppData\Local\Temp\ipykernel_18936\3983147829.py:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corrwith(data.per_square_meter_price)
# floor                             0.185877
# lat                               0.133961
# lng                              -0.223485
# osm_amenity_points_in_0.001       0.439348
# osm_amenity_points_in_0.005       0.489408
#                                     ...
# reform_mean_floor_count_500       0.114983
# reform_mean_year_building_1000   -0.083208
# reform_mean_year_building_500    -0.073135
# total_square                     -0.028438
# realty_type                       0.138283
# Length: 70, dtype: float64

# %% [markdown]
# ### Функция преобразований для улучшения результата

# %%
columns_to_drop = [
    "floor",
    "reform_house_population_1000",
    "reform_house_population_500",
    "reform_mean_floor_count_1000",
    "reform_mean_floor_count_500",
    "reform_mean_year_building_1000",
    "reform_mean_year_building_500",
    "street",
    "city",
    "region",
    "date",
    "id",
    "osm_city_nearest_name",
]


def manipulate(data):
    data.osm_city_nearest_population = data.osm_city_nearest_population.fillna(data.osm_city_nearest_population.mean())
    data = data.assign(
        osm_city_nearest_population=data.osm_city_nearest_population.apply(np.log2),
    )
    # Нормализация
    for i in data.columns:
        if i not in ["per_square_meter_price", *columns_to_drop]:
            minimum, maximum = data[i].min(), data[i].max()
            data[i] = data[i].apply(lambda x: (x - minimum) / (maximum - minimum))
    data = data.drop(columns=columns_to_drop)
    return data

# %%
data = manipulate(data)
data = data.assign(
    per_square_meter_price=data.per_square_meter_price.apply(np.log2),
)
data.corrwith(data.per_square_meter_price)
# Out:
# lat                             0.156673
# lng                            -0.275346
# osm_amenity_points_in_0.001     0.357936
# osm_amenity_points_in_0.005     0.428900
# osm_amenity_points_in_0.0075    0.438521
#                                   ...
# per_square_meter_price          1.000000
# reform_count_of_houses_1000     0.192430
# reform_count_of_houses_500      0.136675
# total_square                   -0.119264
# realty_type                     0.168014
# Length: 63, dtype: float64

# %% [markdown]
# ### Подбор параметров

# %%
def predict_with_param(train_X, train_Y, test_X, test_Y, alpha, max_iter, learning_rate):
    model = SGDRegressor(alpha=alpha, max_iter=max_iter, learning_rate=learning_rate).fit(train_X, train_Y)
    predicted = model.predict(test_X)
    mape = mean_absolute_percentage_error(test_Y, predicted)
    return model, mape

# %%
train_size = int(0.8 * len(data))
train_X, train_Y = data.drop(columns=["per_square_meter_price"])[:train_size], data.per_square_meter_price[:train_size]
test_X, test_Y = data.drop(columns=["per_square_meter_price"])[train_size:], data.per_square_meter_price[train_size:]
params_permutations = [
    (alpha / 10000, max_iter, learning_rate)
    for alpha in range(1, 11)
    for max_iter in range(100, 1001, 100)
    for learning_rate in ["constant", "invscaling", "adaptive"]
]

best_model, best_mape = None, None
for alpha, max_iter, learning_rate in params_permutations:
    model, mape = predict_with_param(train_X, train_Y, test_X, test_Y, alpha, max_iter, learning_rate)
    if best_mape is None or mape < best_mape:
        best_model, best_mape = model, mape
    print("CURRENT:", model, mape)
    print("BEST:", best_model, best_mape)
# Out:
# CURRENT: SGDRegressor(learning_rate='constant', max_iter=100) 0.06748472290323168
# BEST: SGDRegressor(learning_rate='constant', max_iter=100) 0.06748472290323168
# CURRENT: SGDRegressor(max_iter=100) 0.0677113663684961
# BEST: SGDRegressor(learning_rate='constant', max_iter=100) 0.06748472290323168
# CURRENT: SGDRegressor(learning_rate='adaptive', max_iter=100) 0.06711585543185275
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=100) 0.06711585543185275
# CURRENT: SGDRegressor(learning_rate='constant', max_iter=200) 0.06737193543632625
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=100) 0.06711585543185275
# CURRENT: SGDRegressor(max_iter=200) 0.06762214185526637
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=100) 0.06711585543185275
# CURRENT: SGDRegressor(learning_rate='adaptive', max_iter=200) 0.06711925016338778
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=100) 0.06711585543185275
# CURRENT: SGDRegressor(learning_rate='constant', max_iter=300) 0.06753969506195684
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=100) 0.06711585543185275
# CURRENT: SGDRegressor(max_iter=300) 0.067520233276484
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=100) 0.06711585543185275
# CURRENT: SGDRegressor(learning_rate='adaptive', max_iter=300) 0.06711581214587929
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=300) 0.06711581214587929
# CURRENT: SGDRegressor(learning_rate='constant', max_iter=400) 0.06835958042182695
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=300) 0.06711581214587929
# CURRENT: SGDRegressor(max_iter=400) 0.06753981073502964
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=300) 0.06711581214587929
# CURRENT: SGDRegressor(learning_rate='adaptive', max_iter=400) 0.0671165761470205
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=300) 0.06711581214587929
# CURRENT: SGDRegressor(learning_rate='constant', max_iter=500) 0.06798154887368862
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=300) 0.06711581214587929
# CURRENT: SGDRegressor(max_iter=500) 0.06768194557378794
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=300) 0.06711581214587929
# CURRENT: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(learning_rate='constant', max_iter=600) 0.06845780882368367
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(max_iter=600) 0.06773318955624484
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(learning_rate='adaptive', max_iter=600) 0.06711596992816832
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(learning_rate='constant', max_iter=700) 0.06731376184708225
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(max_iter=700) 0.06752447113395546
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(learning_rate='adaptive', max_iter=700) 0.06711897573811734
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(learning_rate='constant', max_iter=800) 0.06735464951851883
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(max_iter=800) 0.06750624132577454
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(learning_rate='adaptive', max_iter=800) 0.067116643696595
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(learning_rate='constant', max_iter=900) 0.06735982142179225
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(max_iter=900) 0.0675152598839307
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(learning_rate='adaptive', max_iter=900) 0.06711777301497569
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(learning_rate='constant') 0.06786009432841232
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor() 0.06760186770671067
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(learning_rate='adaptive') 0.06711615707106043
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, learning_rate='constant', max_iter=100) 0.06752315075220575
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, max_iter=100) 0.06765042916463947
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, learning_rate='adaptive', max_iter=100) 0.06722001455556903
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, learning_rate='constant', max_iter=200) 0.06737131473894188
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, max_iter=200) 0.06761087395871233
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, learning_rate='adaptive', max_iter=200) 0.06721955830183415
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, learning_rate='constant', max_iter=300) 0.06755671382185513
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, max_iter=300) 0.06759011995759134
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, learning_rate='adaptive', max_iter=300) 0.06721906105382976
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, learning_rate='constant', max_iter=400) 0.06976696947917102
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, max_iter=400) 0.06757961166291361
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, learning_rate='adaptive', max_iter=400) 0.06722052467562985
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, learning_rate='constant', max_iter=500) 0.06770706872986249
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, max_iter=500) 0.06770418237360003
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, learning_rate='adaptive', max_iter=500) 0.06722253334591306
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, learning_rate='constant', max_iter=600) 0.06744029148861806
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, max_iter=600) 0.06760139204514222
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, learning_rate='adaptive', max_iter=600) 0.06722150042777027
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, learning_rate='constant', max_iter=700) 0.06876365490932315
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, max_iter=700) 0.06755832142662588
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, learning_rate='adaptive', max_iter=700) 0.06722155077606763
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, learning_rate='constant', max_iter=800) 0.0674089127185583
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, max_iter=800) 0.06762462231468763
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, learning_rate='adaptive', max_iter=800) 0.06722269209134686
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, learning_rate='constant', max_iter=900) 0.06721495113244967
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, max_iter=900) 0.06776474041740094
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, learning_rate='adaptive', max_iter=900) 0.06722246458231791
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, learning_rate='constant') 0.06788765909498516
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002) 0.06762391170877578
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0002, learning_rate='adaptive') 0.06721976859790646
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, learning_rate='constant', max_iter=100) 0.06895550100464273
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, max_iter=100) 0.06767423609321291
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, learning_rate='adaptive', max_iter=100) 0.06732053288196223
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, learning_rate='constant', max_iter=200) 0.0679895381792114
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, max_iter=200) 0.06773902695754672
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, learning_rate='adaptive', max_iter=200) 0.06732576848792035
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, learning_rate='constant', max_iter=300) 0.0676177732938001
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, max_iter=300) 0.06779202365573449
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, learning_rate='adaptive', max_iter=300) 0.06732290107011593
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, learning_rate='constant', max_iter=400) 0.06802666012074332
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, max_iter=400) 0.06772379234157924
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, learning_rate='adaptive', max_iter=400) 0.06732518593219754
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, learning_rate='constant', max_iter=500) 0.067382109545097
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, max_iter=500) 0.06771256175609487
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, learning_rate='adaptive', max_iter=500) 0.0673255045934842
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, learning_rate='constant', max_iter=600) 0.06732000060039757
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, max_iter=600) 0.06767256870230928
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, learning_rate='adaptive', max_iter=600) 0.06732413928611979
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, learning_rate='constant', max_iter=700) 0.06763062414708959
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, max_iter=700) 0.06776813590653548
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, learning_rate='adaptive', max_iter=700) 0.06732541828269391
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, learning_rate='constant', max_iter=800) 0.06781639608679496
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, max_iter=800) 0.06777218788657538
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, learning_rate='adaptive', max_iter=800) 0.06732556649715961
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, learning_rate='constant', max_iter=900) 0.06785791577783844
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, max_iter=900) 0.06778814720889781
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, learning_rate='adaptive', max_iter=900) 0.0673231448662761
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, learning_rate='constant') 0.06741658064521978
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003) 0.0675951888017635
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0003, learning_rate='adaptive') 0.06732513817811996
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, learning_rate='constant', max_iter=100) 0.06730482160702209
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, max_iter=100) 0.06779861366675329
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, learning_rate='adaptive', max_iter=100) 0.06742502655940232
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, learning_rate='constant', max_iter=200) 0.06750842238688365
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, max_iter=200) 0.06776688501839064
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, learning_rate='adaptive', max_iter=200) 0.06742336422590121
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, learning_rate='constant', max_iter=300) 0.06741727751127916
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, max_iter=300) 0.06781545269412487
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, learning_rate='adaptive', max_iter=300) 0.06742297671911844
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, learning_rate='constant', max_iter=400) 0.06810470559617658
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, max_iter=400) 0.06775341805669347
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, learning_rate='adaptive', max_iter=400) 0.06742553386372088
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, learning_rate='constant', max_iter=500) 0.0676345977333337
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, max_iter=500) 0.06777791854358635
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, learning_rate='adaptive', max_iter=500) 0.0674233477948973
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, learning_rate='constant', max_iter=600) 0.0675857892073831
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, max_iter=600) 0.06771774875930836
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, learning_rate='adaptive', max_iter=600) 0.06742310237353483
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, learning_rate='constant', max_iter=700) 0.067995353009383
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, max_iter=700) 0.06773799176030938
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, learning_rate='adaptive', max_iter=700) 0.0674234826815815
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, learning_rate='constant', max_iter=800) 0.06830034050913279
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, max_iter=800) 0.06768903681958241
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, learning_rate='adaptive', max_iter=800) 0.06742116825931108
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, learning_rate='constant', max_iter=900) 0.06771303546087719
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, max_iter=900) 0.06788466626426282
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, learning_rate='adaptive', max_iter=900) 0.06742428702056402
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, learning_rate='constant') 0.06804314541656656
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004) 0.0677243346125977
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0004, learning_rate='adaptive') 0.06742224236982271
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, learning_rate='constant', max_iter=100) 0.06834821807215838
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, max_iter=100) 0.06780002287452166
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, learning_rate='adaptive', max_iter=100) 0.0675193419211608
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, learning_rate='constant', max_iter=200) 0.06765130157363107
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, max_iter=200) 0.06777129642107446
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, learning_rate='adaptive', max_iter=200) 0.06751809760157274
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, learning_rate='constant', max_iter=300) 0.06774473130904499
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, max_iter=300) 0.06784351025488577
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, learning_rate='adaptive', max_iter=300) 0.0675181679831404
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, learning_rate='constant', max_iter=400) 0.06891516703327281
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, max_iter=400) 0.06788349124588117
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, learning_rate='adaptive', max_iter=400) 0.06751911296248611
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, learning_rate='constant', max_iter=500) 0.0679134366132061
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, max_iter=500) 0.06774870602132925
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, learning_rate='adaptive', max_iter=500) 0.06751876728159494
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, learning_rate='constant', max_iter=600) 0.0675413824496337
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, max_iter=600) 0.06776876102857281
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, learning_rate='adaptive', max_iter=600) 0.0675195644515454
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, learning_rate='constant', max_iter=700) 0.06757798846826682
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, max_iter=700) 0.06777455726107942
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, learning_rate='adaptive', max_iter=700) 0.06751829882125479
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, learning_rate='constant', max_iter=800) 0.06770445874889873
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, max_iter=800) 0.0679632868523748
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, learning_rate='adaptive', max_iter=800) 0.06751859540510345
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, learning_rate='constant', max_iter=900) 0.06762908790433274
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, max_iter=900) 0.06777148432825175
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, learning_rate='adaptive', max_iter=900) 0.06751979828797419
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, learning_rate='constant') 0.06768107934479797
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005) 0.06777433549079703
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0005, learning_rate='adaptive') 0.06751948859003615
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, learning_rate='constant', max_iter=100) 0.0676892666590026
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, max_iter=100) 0.06784116963285271
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, learning_rate='adaptive', max_iter=100) 0.06761063496677597
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, learning_rate='constant', max_iter=200) 0.0676884885393741
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, max_iter=200) 0.0678605985728963
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, learning_rate='adaptive', max_iter=200) 0.06761192554813542
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, learning_rate='constant', max_iter=300) 0.06757235641733526
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, max_iter=300) 0.06798102476680742
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, learning_rate='adaptive', max_iter=300) 0.06760949970792386
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, learning_rate='constant', max_iter=400) 0.06999548849346827
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, max_iter=400) 0.06793687148479728
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, learning_rate='adaptive', max_iter=400) 0.06761195721721557
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, learning_rate='constant', max_iter=500) 0.0677131477184378
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, max_iter=500) 0.06802109301963287
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, learning_rate='adaptive', max_iter=500) 0.06761166632537015
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, learning_rate='constant', max_iter=600) 0.06758897221936136
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, max_iter=600) 0.06799815244867537
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, learning_rate='adaptive', max_iter=600) 0.06761038622650259
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, learning_rate='constant', max_iter=700) 0.06765636352982342
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, max_iter=700) 0.06791937739177532
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, learning_rate='adaptive', max_iter=700) 0.06761101063744762
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, learning_rate='constant', max_iter=800) 0.06765071654157061
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, max_iter=800) 0.06789243250690577
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, learning_rate='adaptive', max_iter=800) 0.0676123255128647
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, learning_rate='constant', max_iter=900) 0.06807291080725464
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, max_iter=900) 0.06788441685994166
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, learning_rate='adaptive', max_iter=900) 0.06761281842043862
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, learning_rate='constant') 0.06822033596546274
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006) 0.06788655208943935
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0006, learning_rate='adaptive') 0.06761087657782283
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, learning_rate='constant', max_iter=100) 0.06779181696973276
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, max_iter=100) 0.0679211800723051
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, learning_rate='adaptive', max_iter=100) 0.06769904049938776
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, learning_rate='constant', max_iter=200) 0.06798820819517257
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, max_iter=200) 0.06792153079597679
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, learning_rate='adaptive', max_iter=200) 0.06769679148516022
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, learning_rate='constant', max_iter=300) 0.06846467423950392
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, max_iter=300) 0.06797824961955526
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, learning_rate='adaptive', max_iter=300) 0.06769864425674348
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, learning_rate='constant', max_iter=400) 0.06781001946279541
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, max_iter=400) 0.06787616651255778
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, learning_rate='adaptive', max_iter=400) 0.06769928358223226
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, learning_rate='constant', max_iter=500) 0.06819780034824735
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, max_iter=500) 0.06787642137576821
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, learning_rate='adaptive', max_iter=500) 0.06770004943022057
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, learning_rate='constant', max_iter=600) 0.06826705294119956
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, max_iter=600) 0.06799596336281562
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, learning_rate='adaptive', max_iter=600) 0.06769743288682373
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, learning_rate='constant', max_iter=700) 0.06792226849577374
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, max_iter=700) 0.06805491428334846
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, learning_rate='adaptive', max_iter=700) 0.06769947585381297
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, learning_rate='constant', max_iter=800) 0.06798689549865096
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, max_iter=800) 0.0679370674992049
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, learning_rate='adaptive', max_iter=800) 0.06769731456470404
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, learning_rate='constant', max_iter=900) 0.06801438417448574
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, max_iter=900) 0.0679637813867852
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, learning_rate='adaptive', max_iter=900) 0.06769672559177457
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, learning_rate='constant') 0.06791328715634504
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007) 0.06791198889963249
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0007, learning_rate='adaptive') 0.06770219014445374
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, learning_rate='constant', max_iter=100) 0.07208820045547731
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, max_iter=100) 0.06796341878943142
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, learning_rate='adaptive', max_iter=100) 0.06778242904900372
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, learning_rate='constant', max_iter=200) 0.06809102842988986
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, max_iter=200) 0.06801460803441377
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, learning_rate='adaptive', max_iter=200) 0.06778238263593038
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, learning_rate='constant', max_iter=300) 0.06872113745157413
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, max_iter=300) 0.06809702028945465
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, learning_rate='adaptive', max_iter=300) 0.06778229983072827
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, learning_rate='constant', max_iter=400) 0.07066190924038375
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, max_iter=400) 0.06800069337738794
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, learning_rate='adaptive', max_iter=400) 0.06778274205714074
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, learning_rate='constant', max_iter=500) 0.06793399305044237
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, max_iter=500) 0.06802452803803045
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, learning_rate='adaptive', max_iter=500) 0.0677807657412501
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, learning_rate='constant', max_iter=600) 0.06824274070687321
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, max_iter=600) 0.06810539724907741
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, learning_rate='adaptive', max_iter=600) 0.06778274506651968
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, learning_rate='constant', max_iter=700) 0.06773557173332993
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, max_iter=700) 0.06803220732101721
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, learning_rate='adaptive', max_iter=700) 0.06778279667847205
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, learning_rate='constant', max_iter=800) 0.06808351553791138
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, max_iter=800) 0.06807062872520554
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, learning_rate='adaptive', max_iter=800) 0.06778317920748432
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, learning_rate='constant', max_iter=900) 0.06782107554833058
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, max_iter=900) 0.06795175545869545
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, learning_rate='adaptive', max_iter=900) 0.06778131490040727
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, learning_rate='constant') 0.06772515420692055
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008) 0.0680477394918941
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0008, learning_rate='adaptive') 0.06778190807702683
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, learning_rate='constant', max_iter=100) 0.06781807059259372
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, max_iter=100) 0.06809173137590702
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, learning_rate='adaptive', max_iter=100) 0.06786301234486306
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, learning_rate='constant', max_iter=200) 0.06818718044541303
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, max_iter=200) 0.06801724269652544
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, learning_rate='adaptive', max_iter=200) 0.06786272531644189
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, learning_rate='constant', max_iter=300) 0.06797479753889477
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, max_iter=300) 0.06825813595828685
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, learning_rate='adaptive', max_iter=300) 0.06786299930202008
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, learning_rate='constant', max_iter=400) 0.06990369071021027
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, max_iter=400) 0.06816659028987206
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, learning_rate='adaptive', max_iter=400) 0.06786400296973157
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, learning_rate='constant', max_iter=500) 0.06976618668135923
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, max_iter=500) 0.06806693262023696
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, learning_rate='adaptive', max_iter=500) 0.06786222343217839
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, learning_rate='constant', max_iter=600) 0.0681598667410285
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, max_iter=600) 0.06805095700004417
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, learning_rate='adaptive', max_iter=600) 0.06786394289937764
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, learning_rate='constant', max_iter=700) 0.06781333400784109
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, max_iter=700) 0.06803318725325608
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, learning_rate='adaptive', max_iter=700) 0.0678628059127141
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, learning_rate='constant', max_iter=800) 0.06799496346432365
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, max_iter=800) 0.06823919125497288
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, learning_rate='adaptive', max_iter=800) 0.06786127356212916
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, learning_rate='constant', max_iter=900) 0.0683013401088881
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, max_iter=900) 0.06807513064809873
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, learning_rate='adaptive', max_iter=900) 0.06786254074130751
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, learning_rate='constant') 0.06945515859114795
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009) 0.06804746646085179
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.0009, learning_rate='adaptive') 0.06786263676536429
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, learning_rate='constant', max_iter=100) 0.070995801038227
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, max_iter=100) 0.06809231665820366
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, learning_rate='adaptive', max_iter=100) 0.06793683310156567
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, learning_rate='constant', max_iter=200) 0.06801196875026769
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, max_iter=200) 0.06815322485335121
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, learning_rate='adaptive', max_iter=200) 0.06793782364143819
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, learning_rate='constant', max_iter=300) 0.0697092357707691
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, max_iter=300) 0.06816266833407103
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, learning_rate='adaptive', max_iter=300) 0.06794056847285075
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, learning_rate='constant', max_iter=400) 0.0687306949404026
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, max_iter=400) 0.06823320602403654
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, learning_rate='adaptive', max_iter=400) 0.06793735868513287
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, learning_rate='constant', max_iter=500) 0.067956935971464
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, max_iter=500) 0.06812892693738039
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, learning_rate='adaptive', max_iter=500) 0.06793778987561033
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, learning_rate='constant', max_iter=600) 0.06785222845125122
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, max_iter=600) 0.06830601664200045
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, learning_rate='adaptive', max_iter=600) 0.06793683682671348
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, learning_rate='constant', max_iter=700) 0.06800159250219041
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, max_iter=700) 0.06817665941816763
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, learning_rate='adaptive', max_iter=700) 0.06794064541653884
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, learning_rate='constant', max_iter=800) 0.06836270493201121
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, max_iter=800) 0.06821364350634117
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, learning_rate='adaptive', max_iter=800) 0.0679416968826256
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, learning_rate='constant', max_iter=900) 0.0678798910123624
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, max_iter=900) 0.06811642090684651
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, learning_rate='adaptive', max_iter=900) 0.06793918509434434
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, learning_rate='constant') 0.06994744890287298
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001) 0.06807653822340178
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653
# CURRENT: SGDRegressor(alpha=0.001, learning_rate='adaptive') 0.06793751847540774
# BEST: SGDRegressor(learning_rate='adaptive', max_iter=500) 0.06711507841406653

# %% [markdown]
# ### Смотрим счет модели

# %%
X = data.drop(columns=["per_square_meter_price"])
Y = data.per_square_meter_price

model = best_model.fit(X, Y)
model.score(X, Y)
# Out:
# 0.41766414263378204

# %% [markdown]
# ### Запускаем на тестовых данных

# %%
test_data = pd.read_csv("data/test_x.csv")
test_data = manipulate(test_data)
result = model.predict(test_data)

# %% [markdown]
# ### Записываем результаты в `result.csv`

# %%
sample = pd.read_csv("data/sample_submission.csv")
sample["per_square_meter_price"] = result[:len(sample)]
sample.per_square_meter_price = sample.per_square_meter_price.apply(lambda x: 2 ** x / 4)
sample.to_csv("result.csv", index=False)
